# %% [markdown]
# # LOW CURRENT OCV AT -10 degree celcius

# %%
import pandas as pd 


# Read a specific sheet by name
low_curr_ocv_minus_10= pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV-10-20120629\A1-007-OCV-10-20120629.xlsx", sheet_name=1)


low_curr_ocv_minus_10.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.010944 2012-06-29 16:51:38      3.010944           1
# 1           2      3.026961 2012-06-29 16:51:38      0.015765           2
# 2           3      8.035992 2012-06-29 16:51:44      5.007575           3
# 3           4     13.043648 2012-06-29 16:51:49     10.015231           3
# 4           5     18.051127 2012-06-29 16:51:54     15.022710           3
# 5           6     23.058702 2012-06-29 16:51:59     20.030285           3
# 6           7     28.066285 2012-06-29 16:52:04     25.037868           3
# 7           8     33.073845 2012-06-29 16:52:09     30.045427           3
# 8           9     38.081417 2012-06-29 16:52:14     35.053000           3
# 9          10     43.089009 2012-06-29 16:52:19     40.060591           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.480732             0.000000
# ...

# %%
low_curr_ocv_minus_10.describe()
# Out:
#         Data_Point   Test_Time(s)                      Date_Time  \
# count  29785.00000   29785.000000                          29785
# mean   14893.00000   79452.354943  2012-06-30 14:55:48.690951936
# min        1.00000       3.010944            2012-06-29 16:51:38
# 25%     7447.00000   40580.632806            2012-06-30 04:07:57
# 50%    14893.00000   77867.013967            2012-06-30 14:29:23
# 75%    22339.00000  118452.093694            2012-07-01 01:45:49
# max    29785.00000  159037.139119            2012-07-01 13:02:14
# std     8598.33322   44515.946548                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  29785.000000  29785.000000      29785.0  29785.000000  29785.000000
# mean   36718.816502      5.960987          1.0     -0.001474      3.250768
# min        0.015765      1.000000          1.0     -0.050016      1.999740
# 25%    18022.251663      5.000000          1.0     -0.049995      3.212048
# ...

# %%
low_curr_ocv_minus_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29785 entries, 0 to 29784
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                29785 non-null  int64
#  1   Test_Time(s)              29785 non-null  float64
#  2   Date_Time                 29785 non-null  datetime64[ns]
#  3   Step_Time(s)              29785 non-null  float64
#  4   Step_Index                29785 non-null  int64
#  5   Cycle_Index               29785 non-null  int64
#  6   Current(A)                29785 non-null  float64
#  7   Voltage(V)                29785 non-null  float64
#  8   Charge_Capacity(Ah)       29785 non-null  float64
#  9   Discharge_Capacity(Ah)    29785 non-null  float64
#  10  Charge_Energy(Wh)         29785 non-null  float64
#  11  Discharge_Energy(Wh)      29785 non-null  float64
#  12  dV/dt(V/s)                29785 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 0 degree celcius

# %%
low_curr_ocv_0=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV0-20120618\A1-007-OCV0-20120618.xlsx", sheet_name=1)

# %%
low_curr_ocv_0.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.014942 2012-06-18 11:49:18      3.014942           1
# 1           2      3.046301 2012-06-18 11:49:18      0.031089           2
# 2           3      8.054232 2012-06-18 11:49:23      5.007584           3
# 3           4     13.061941 2012-06-18 11:49:28     10.015293           3
# 4           5     18.073395 2012-06-18 11:49:33     15.026747           3
# 5           6     23.080863 2012-06-18 11:49:38     20.034215           3
# 6           7     28.088504 2012-06-18 11:49:43     25.041856           3
# 7           8     33.096150 2012-06-18 11:49:48     30.049501           3
# 8           9     38.103670 2012-06-18 11:49:53     35.057022           3
# 9          10     43.111231 2012-06-18 11:49:58     40.064583           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.374551             0.000000
# ...

# %%
low_curr_ocv_0.describe()
# Out:
#          Data_Point   Test_Time(s)                      Date_Time  \
# count  30249.000000   30249.000000                          30249
# mean   15125.000000   80615.643879  2012-06-19 10:12:51.466792448
# min        1.000000       3.014942            2012-06-18 11:49:18
# 25%     7563.000000   41162.668955            2012-06-18 23:15:18
# 50%    15125.000000   79029.928468            2012-06-19 09:46:26
# 75%    22687.000000  120193.073943            2012-06-19 21:12:29
# max    30249.000000  161359.267642            2012-06-20 08:38:36
# std     8732.278483   45209.697396                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  30249.000000  30249.000000      30249.0  30249.000000  30249.000000
# mean   36962.274515      5.962048          1.0     -0.000406      3.272463
# min        0.031089      1.000000          1.0     -0.050002      1.999740
# ...

# %%
low_curr_ocv_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30249 entries, 0 to 30248
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                30249 non-null  int64
#  1   Test_Time(s)              30249 non-null  float64
#  2   Date_Time                 30249 non-null  datetime64[ns]
#  3   Step_Time(s)              30249 non-null  float64
#  4   Step_Index                30249 non-null  int64
#  5   Cycle_Index               30249 non-null  int64
#  6   Current(A)                30249 non-null  float64
#  7   Voltage(V)                30249 non-null  float64
#  8   Charge_Capacity(Ah)       30249 non-null  float64
#  9   Discharge_Capacity(Ah)    30249 non-null  float64
#  10  Charge_Energy(Wh)         30249 non-null  float64
#  11  Discharge_Energy(Wh)      30249 non-null  float64
#  12  dV/dt(V/s)                30249 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 10 degree celcius

# %%
low_curr_ocv_10=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV10-20120611\A1-007-OCV10-20120611.xlsx",sheet_name=1)

# %%
low_curr_ocv_10.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.014079 2012-06-11 18:47:47      3.014079           1
# 1           2      3.025053 2012-06-11 18:47:47      0.000002           2
# 2           3      8.032849 2012-06-11 18:47:52      5.007554           3
# 3           4     13.040499 2012-06-11 18:47:57     10.015204           3
# 4           5     18.046321 2012-06-11 18:48:02     15.021026           3
# 5           6     23.053825 2012-06-11 18:48:07     20.028530           3
# 6           7     28.061527 2012-06-11 18:48:12     25.036233           3
# 7           8     33.068989 2012-06-11 18:48:17     30.043694           3
# 8           9     38.076571 2012-06-11 18:48:22     35.051276           3
# 9          10     43.084085 2012-06-11 18:48:27     40.058790           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.306226         0.000000e+00
# ...

# %%
low_curr_ocv_10.describe()
# Out:
#         Data_Point   Test_Time(s)                      Date_Time  \
# count  31898.00000   31898.000000                          31898
# mean   15949.50000   84407.542774  2012-06-12 23:21:28.604269824
# min        1.00000       3.014079            2012-06-11 18:47:47
# 25%     7975.25000   43127.482188  2012-06-12 12:56:42.249999872
# 50%    15949.50000   83059.113340     2012-06-13 00:02:14.500000
# 75%    23923.75000  126287.349589  2012-06-13 12:02:42.750000128
# max    31898.00000  169513.642825            2012-06-14 00:03:10
# std     9208.30378   47856.153587                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  31898.000000  31898.000000      31898.0  31898.000000  31898.000000
# mean   35034.642104      5.807605          1.0      0.010184      3.296589
# min        0.000002      1.000000          1.0     -0.050002      1.999740
# 25%    14612.052933      5.000000          1.0     -0.049995      3.254521
# ...

# %%
low_curr_ocv_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31898 entries, 0 to 31897
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                31898 non-null  int64
#  1   Test_Time(s)              31898 non-null  float64
#  2   Date_Time                 31898 non-null  datetime64[ns]
#  3   Step_Time(s)              31898 non-null  float64
#  4   Step_Index                31898 non-null  int64
#  5   Cycle_Index               31898 non-null  int64
#  6   Current(A)                31898 non-null  float64
#  7   Voltage(V)                31898 non-null  float64
#  8   Charge_Capacity(Ah)       31898 non-null  float64
#  9   Discharge_Capacity(Ah)    31898 non-null  float64
#  10  Charge_Energy(Wh)         31898 non-null  float64
#  11  Discharge_Energy(Wh)      31898 non-null  float64
#  12  dV/dt(V/s)                31898 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 20 degree celcius

# %%
low_curr_ocv_20=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV20-20120614\A1-007-OCV20-20120614.xlsx",sheet_name=1)

# %%
low_curr_ocv_20.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.007810 2012-06-14 12:13:15      3.007810           1
# 1           2      3.008080 2012-06-14 12:13:15      0.000002           2
# 2           3      8.015990 2012-06-14 12:13:20      5.007662           3
# 3           4     13.023481 2012-06-14 12:13:25     10.015153           3
# 4           5     18.035039 2012-06-14 12:13:30     15.026711           3
# 5           6     23.042624 2012-06-14 12:13:35     20.034296           3
# 6           7     28.050181 2012-06-14 12:13:40     25.041853           3
# 7           8     33.057714 2012-06-14 12:13:45     30.049386           3
# 8           9     38.065421 2012-06-14 12:13:50     35.057093           3
# 9          10     43.072973 2012-06-14 12:13:55     40.064645           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.370858         0.000000e+00
# ...

# %%
low_curr_ocv_20.describe()
# Out:
#          Data_Point   Test_Time(s)                      Date_Time  \
# count  31018.000000   31018.000000                          31018
# mean   15509.500000   82530.938666  2012-06-15 11:08:43.815655168
# min        1.000000       3.007810            2012-06-14 12:13:15
# 25%     7755.250000   42125.027738  2012-06-14 23:55:17.249999872
# 50%    15509.500000   80954.993049     2012-06-15 10:42:27.500000
# 75%    23263.750000  123082.373990  2012-06-15 22:24:35.750000128
# max    31018.000000  165211.592285            2012-06-16 10:06:45
# std     8954.269661   46356.820098                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  31018.000000  31018.000000      31018.0  31018.000000  31018.000000
# mean   37436.752180      5.955671          1.0      0.000552      3.282977
# min        0.000002      1.000000          1.0     -0.050002      1.999740
# ...

# %%
low_curr_ocv_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31018 entries, 0 to 31017
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                31018 non-null  int64
#  1   Test_Time(s)              31018 non-null  float64
#  2   Date_Time                 31018 non-null  datetime64[ns]
#  3   Step_Time(s)              31018 non-null  float64
#  4   Step_Index                31018 non-null  int64
#  5   Cycle_Index               31018 non-null  int64
#  6   Current(A)                31018 non-null  float64
#  7   Voltage(V)                31018 non-null  float64
#  8   Charge_Capacity(Ah)       31018 non-null  float64
#  9   Discharge_Capacity(Ah)    31018 non-null  float64
#  10  Charge_Energy(Wh)         31018 non-null  float64
#  11  Discharge_Energy(Wh)      31018 non-null  float64
#  12  dV/dt(V/s)                31018 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 25 degree celcius

# %%
low_curr_ocv_25=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV25-20120905\A1-007-OCV-25-20120905.xlsx",sheet_name=1)

# %%
low_curr_ocv_25.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.003881 2012-09-05 09:50:31      3.003881           1
# 1           2      8.004174 2012-09-05 09:50:36      5.000008           2
# 2           3     13.004248 2012-09-05 09:50:41     10.000082           2
# 3           4     18.004260 2012-09-05 09:50:46     15.000093           2
# 4           5     23.005579 2012-09-05 09:50:51     20.001413           2
# 5           6     28.005657 2012-09-05 09:50:56     25.001492           2
# 6           7     33.011929 2012-09-05 09:51:01     30.007763           2
# 7           8     38.011951 2012-09-05 09:51:06     35.007785           2
# 8           9     43.011997 2012-09-05 09:51:11     40.007831           2
# 9          10     48.012036 2012-09-05 09:51:16     45.007870           2
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    2.897814             0.000000
# ...

# %%
low_curr_ocv_25.describe()
# Out:
#         Data_Point   Test_Time(s)                      Date_Time  \
# count  32307.00000   32307.000000                          32307
# mean   16154.00000   85506.863991  2012-09-06 09:35:35.959884800
# min        1.00000       3.003881            2012-09-05 09:50:31
# 25%     8077.50000   43696.841249     2012-09-05 21:58:45.500000
# 50%    16154.00000   84091.821468            2012-09-06 09:12:01
# 75%    24230.50000  127800.461601     2012-09-06 21:20:30.500000
# max    32307.00000  171495.535618            2012-09-07 09:28:46
# std     9326.37191   48357.812231                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  32307.000000  32307.000000      32307.0  32307.000000  32307.000000
# mean   36302.546619      5.837713          1.0      0.023235      3.294757
# min        3.003881      1.000000          1.0     -0.050016      1.999724
# 25%    15874.938811      5.000000          1.0     -0.049991      3.264374
# ...

# %%
low_curr_ocv_25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32307 entries, 0 to 32306
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                32307 non-null  int64
#  1   Test_Time(s)              32307 non-null  float64
#  2   Date_Time                 32307 non-null  datetime64[ns]
#  3   Step_Time(s)              32307 non-null  float64
#  4   Step_Index                32307 non-null  int64
#  5   Cycle_Index               32307 non-null  int64
#  6   Current(A)                32307 non-null  float64
#  7   Voltage(V)                32307 non-null  float64
#  8   Charge_Capacity(Ah)       32307 non-null  float64
#  9   Discharge_Capacity(Ah)    32307 non-null  float64
#  10  Charge_Energy(Wh)         32307 non-null  float64
#  11  Discharge_Energy(Wh)      32307 non-null  float64
#  12  dV/dt(V/s)                32307 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 30 degree celcius

# %%
low_curr_ocv_30=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV30-20120625\A1-007-OCV30-20120625.xlsx",sheet_name=1)

# %%
low_curr_ocv_30.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.010808 2012-06-25 10:58:13      3.010808           1
# 1           2      3.041952 2012-06-25 10:58:13      0.030896           2
# 2           3      8.057809 2012-06-25 10:58:18      5.015575           3
# 3           4     13.065362 2012-06-25 10:58:23     10.023128           3
# 4           5     18.072954 2012-06-25 10:58:28     15.030720           3
# 5           6     23.080509 2012-06-25 10:58:33     20.038275           3
# 6           7     28.088092 2012-06-25 10:58:38     25.045859           3
# 7           8     33.095648 2012-06-25 10:58:43     30.053414           3
# 8           9     38.103228 2012-06-25 10:58:48     35.060994           3
# 9          10     43.110795 2012-06-25 10:58:53     40.068561           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.358855             0.000000
# ...

# %%
low_curr_ocv_30.describe()
# Out:
#          Data_Point   Test_Time(s)                      Date_Time  \
# count  31150.000000   31150.000000                          31150
# mean   15575.500000   82879.119805  2012-06-26 09:59:30.199871488
# min        1.000000       3.010808            2012-06-25 10:58:13
# 25%     7788.250000   42289.364036  2012-06-25 22:43:00.249999872
# 50%    15575.500000   81284.579150     2012-06-26 09:32:55.500000
# 75%    23362.750000  123576.509714  2012-06-26 21:17:47.750000128
# max    31150.000000  165868.338984            2012-06-27 09:02:40
# std     8992.374779   46527.087207                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  31150.000000  31150.000000      31150.0  31150.000000  31150.000000
# mean   37868.880320      5.967159          1.0      0.000752      3.282232
# min        0.030896      1.000000          1.0     -0.050016      1.999740
# ...

# %%
low_curr_ocv_30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31150 entries, 0 to 31149
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                31150 non-null  int64
#  1   Test_Time(s)              31150 non-null  float64
#  2   Date_Time                 31150 non-null  datetime64[ns]
#  3   Step_Time(s)              31150 non-null  float64
#  4   Step_Index                31150 non-null  int64
#  5   Cycle_Index               31150 non-null  int64
#  6   Current(A)                31150 non-null  float64
#  7   Voltage(V)                31150 non-null  float64
#  8   Charge_Capacity(Ah)       31150 non-null  float64
#  9   Discharge_Capacity(Ah)    31150 non-null  float64
#  10  Charge_Energy(Wh)         31150 non-null  float64
#  11  Discharge_Energy(Wh)      31150 non-null  float64
#  12  dV/dt(V/s)                31150 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 40 degree celcius

# %%
low_curr_ocv_40=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV40-20120627\A1-007-OCV40-20120627.xlsx",sheet_name=1)

# %%
low_curr_ocv_40.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.010283 2012-06-27 11:43:25      3.010283           1
# 1           2      3.026131 2012-06-27 11:43:25      0.015609           2
# 2           3      8.033910 2012-06-27 11:43:30      5.007549           3
# 3           4     13.041500 2012-06-27 11:43:35     10.015140           3
# 4           5     18.049071 2012-06-27 11:43:40     15.022711           3
# 5           6     23.056643 2012-06-27 11:43:45     20.030282           3
# 6           7     28.064215 2012-06-27 11:43:50     25.037854           3
# 7           8     33.071785 2012-06-27 11:43:55     30.045425           3
# 8           9     38.079286 2012-06-27 11:44:00     35.052926           3
# 9          10     43.086932 2012-06-27 11:44:05     40.060571           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.440106             0.000000
# ...

# %%
low_curr_ocv_40.describe()
# Out:
#          Data_Point   Test_Time(s)                      Date_Time  \
# count  31258.000000   31258.000000                          31258
# mean   15629.500000   83182.146533  2012-06-28 10:49:45.445390080
# min        1.000000       3.010283            2012-06-27 11:43:25
# 25%     7815.250000   42427.009169  2012-06-27 23:30:30.249999872
# 50%    15629.500000   81557.428742     2012-06-28 10:22:40.500000
# 75%    23443.750000  123985.717499  2012-06-28 22:09:49.750000128
# max    31258.000000  166414.916638            2012-06-29 09:56:59
# std     9023.551694   46653.945691                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  31258.000000  31258.000000      31258.0  31258.000000  31258.000000
# mean   38403.674272      5.985124          1.0      0.000176      3.281685
# min        0.015609      1.000000          1.0     -0.050013      1.999740
# ...

# %%
low_curr_ocv_40.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31258 entries, 0 to 31257
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                31258 non-null  int64
#  1   Test_Time(s)              31258 non-null  float64
#  2   Date_Time                 31258 non-null  datetime64[ns]
#  3   Step_Time(s)              31258 non-null  float64
#  4   Step_Index                31258 non-null  int64
#  5   Cycle_Index               31258 non-null  int64
#  6   Current(A)                31258 non-null  float64
#  7   Voltage(V)                31258 non-null  float64
#  8   Charge_Capacity(Ah)       31258 non-null  float64
#  9   Discharge_Capacity(Ah)    31258 non-null  float64
#  10  Charge_Energy(Wh)         31258 non-null  float64
#  11  Discharge_Energy(Wh)      31258 non-null  float64
#  12  dV/dt(V/s)                31258 non-null  float64
# ...

# %% [markdown]
# # LOW CURRENT OCV AT 50 degree celcius

# %%
low_curr_ocv_50=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Low Current OCV\OCV50-20120702\A1-007-OCV50-20120702.xlsx",sheet_name=1)

# %%
low_curr_ocv_50.head(10)
# Out:
#    Data_Point  Test_Time(s)           Date_Time  Step_Time(s)  Step_Index  \
# 0           1      3.008714 2012-07-02 10:52:00      3.008714           1
# 1           2      3.020297 2012-07-02 10:52:00      0.000002           2
# 2           3      8.037763 2012-07-02 10:52:05      5.007566           3
# 3           4     13.045325 2012-07-02 10:52:10     10.015128           3
# 4           5     18.052910 2012-07-02 10:52:15     15.022712           3
# 5           6     23.060484 2012-07-02 10:52:20     20.030287           3
# 6           7     28.068046 2012-07-02 10:52:25     25.037848           3
# 7           8     33.075622 2012-07-02 10:52:30     30.045425           3
# 8           9     38.083297 2012-07-02 10:52:35     35.053100           3
# 9          10     43.090758 2012-07-02 10:52:40     40.060561           3
#
#    Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0            1    0.000000    3.352392         0.000000e+00
# ...

# %%
low_curr_ocv_50.describe()
# Out:
#          Data_Point   Test_Time(s)                      Date_Time  \
# count  31475.000000   31475.000000                          31475
# mean   15738.000000   83704.689997  2012-07-03 10:07:02.332041216
# min        1.000000       3.008714            2012-07-02 10:52:00
# 25%     7869.500000   42695.210585     2012-07-02 22:43:32.500000
# 50%    15738.000000   82097.290906            2012-07-03 09:40:15
# 75%    23606.500000  124794.372180     2012-07-03 21:31:52.500000
# max    31475.000000  167494.127364            2012-07-04 09:23:33
# std     9086.194198   46988.606063                            NaN
#
#        Step_Time(s)    Step_Index  Cycle_Index    Current(A)    Voltage(V)  \
# count  31475.000000  31475.000000      31475.0  31475.000000  31475.000000
# mean   38368.988081      5.975473          1.0      0.001542      3.283047
# min        0.000002      1.000000          1.0     -0.050013      1.999740
# ...

# %%
low_curr_ocv_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31475 entries, 0 to 31474
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Data_Point                31475 non-null  int64
#  1   Test_Time(s)              31475 non-null  float64
#  2   Date_Time                 31475 non-null  datetime64[ns]
#  3   Step_Time(s)              31475 non-null  float64
#  4   Step_Index                31475 non-null  int64
#  5   Cycle_Index               31475 non-null  int64
#  6   Current(A)                31475 non-null  float64
#  7   Voltage(V)                31475 non-null  float64
#  8   Charge_Capacity(Ah)       31475 non-null  float64
#  9   Discharge_Capacity(Ah)    31475 non-null  float64
#  10  Charge_Energy(Wh)         31475 non-null  float64
#  11  Discharge_Energy(Wh)      31475 non-null  float64
#  12  dV/dt(V/s)                31475 non-null  float64
# ...

# %% [markdown]
# # DYNAMIC TEST PROFILES

# %% [markdown]
# ## Dynamic test profile at -10 degree celcius

# %%
dst_minus_10=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-N10\A1-007-DST-US06-FUDS-N10-20120829.xlsx",sheet_name=2)

# %%
dst_minus_10.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.003816      3.003816           1    0.000000    2.803019
# 1      8.004204      5.000077           2   -1.099373    2.109292
# 2     12.006524      9.002396           2   -1.099373    1.999416
# 3     17.013409      5.003358           3    0.000000    2.671906
# 4     22.015560     10.005508           3    0.000000    2.689757
# 5     27.017961     15.007909           3    0.000000    2.697759
# 6     32.018054     20.008003           3    0.000000    2.702376
# 7     37.026317     25.016265           3    0.000000    2.706993
# 8     42.030830     30.020778           3    0.000000    2.709763
# 9     47.039970     35.029918           3    0.000000    2.713148
#
#    Temperature (C)_1
# 0          -8.300812
# 1          -8.145514
# 2          -8.145514
# 3          -8.145514
# 4          -8.223158
# 5          -8.191391
# 6          -8.223158
# 7          -8.113752
# 8          -8.067879
# ...

# %%
dst_minus_10.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  19784.000000  1.978400e+04  19784.000000  19784.000000  19784.000000
# mean   20198.292967  8.537425e+02     15.393095     -0.322788      3.165822
# std     9740.553386  1.314745e+03      6.824850      0.887062      0.304046
# min        3.003816  3.849596e-07      1.000000     -3.849595      1.999416
# 25%    11169.170425  1.615422e+02      8.000000     -0.758130      2.985145
# 50%    20727.640514  3.380252e+02     16.000000     -0.008637      3.164809
# 75%    30207.416255  8.841617e+02     24.000000      0.134114      3.347782
# max    35460.091077  7.315288e+03     27.000000      2.061261      3.814677
#
#        Temperature (C)_1
# count       19784.000000
# mean           -7.780438
# std             0.771371
# min            -9.123863
# 25%            -8.505587
# 50%            -7.835041
# 75%            -7.105399
# max            -5.779083

# %%
dst_minus_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19784 entries, 0 to 19783
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       19784 non-null  float64
#  1   Step_Time(s)       19784 non-null  float64
#  2   Step_Index         19784 non-null  int64
#  3   Current(A)         19784 non-null  float64
#  4   Voltage(V)         19784 non-null  float64
#  5   Temperature (C)_1  19784 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 927.5 KB

# %% [markdown]
# ## Dynamic test profile at 0 degree celcius

# %%
dst_0=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-0\A1-007-DST-US06-FUDS-0-20120813.xlsx",sheet_name=2)

# %%
dst_0.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.057882      3.005927           1    0.000000    2.846107
# 1      8.065274      5.007092           2   -1.099185    2.468466
# 2     13.072544     10.014362           2   -1.099373    2.403833
# 3     18.077826     15.019644           2   -1.099373    2.333968
# 4     23.078087     20.019905           2   -1.099373    2.250561
# 5     28.082401     25.024220           2   -1.099560    2.134222
# 6     31.764519     28.706338           2   -1.099373    1.999416
# 7     36.774210      5.008228           3    0.000000    2.548488
# 8     41.783489     10.017507           3    0.000000    2.566955
# 9     46.792691     15.026708           3    0.000000    2.577727
#
#    Temperature (C)_1
# 0           1.256174
# 1           1.256174
# 2           1.332009
# 3           1.256174
# 4           1.301033
# 5           1.452703
# 6           1.345893
# 7           1.332009
# 8           1.376867
# ...

# %%
dst_0.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  23248.000000  2.324800e+04  23248.000000  23248.000000  23248.000000
# mean   20466.229194  5.328935e+02     15.566027     -0.348093      3.165784
# std    10301.715583  6.231313e+02      6.763405      0.918652      0.259291
# min        3.057882  7.699193e-07      1.000000     -3.849219      1.961867
# 25%    10658.417985  1.537679e+02      8.000000     -0.829459      3.026156
# 50%    20792.540701  3.166302e+02     16.000000     -0.191961      3.172349
# 75%    30805.391681  6.670666e+02     24.000000      0.080958      3.293613
# max    36926.114253  4.328226e+03     27.000000      2.060698      3.728192
#
#        Temperature (C)_1
# count       23248.000000
# mean            0.758652
# std             0.513072
# min            -0.521931
# 25%             0.414654
# 50%             0.683727
# 75%             1.083241
# max             3.665956

# %%
dst_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23248 entries, 0 to 23247
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       23248 non-null  float64
#  1   Step_Time(s)       23248 non-null  float64
#  2   Step_Index         23248 non-null  int64
#  3   Current(A)         23248 non-null  float64
#  4   Voltage(V)         23248 non-null  float64
#  5   Temperature (C)_1  23248 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Dynamic test profile at 10 degree celcius

# %%
dst_10=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-10\A1-007-DST-US06-FUDS-10-20120815.xlsx",sheet_name=2)

# %%
dst_10.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.008291      3.008291           1    0.000000    2.968602
# 1      8.015758      5.007161           2   -1.099185    2.729152
# 2     13.018937     10.010341           2   -1.099373    2.703299
# 3     18.027239     15.018642           2   -1.099373    2.678369
# 4     23.031320     20.022724           2   -1.099373    2.654363
# 5     28.035736     25.027140           2   -1.099373    2.629125
# 6     33.039112     30.030516           2   -1.099373    2.603272
# 7     38.047386     35.038790           2   -1.099373    2.576496
# 8     43.053577     40.044981           2   -1.099373    2.547873
# 9     48.062643     45.054046           2   -1.099373    2.515864
#
#    Temperature (C)_1
# 0           9.646121
# 1           9.690903
# 2           9.598107
# 3           9.797547
# 4           9.766615
# 5           9.721836
# 6           9.797547
# 7           9.690903
# 8           9.918034
# ...

# %%
dst_10.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  23881.000000  2.388100e+04  23881.000000  23881.000000  23881.000000
# mean   19919.260228  4.755559e+02     15.518613     -0.356659      3.190354
# std    10203.319502  4.779053e+02      6.705619      0.932044      0.224014
# min        3.008291  7.699193e-07      1.000000     -3.849407      1.987413
# 25%    10199.540085  1.497195e+02      8.000000     -0.848430      3.077862
# 50%    20191.833861  3.095074e+02     16.000000     -0.243238      3.196048
# 75%    30156.128886  5.997450e+02     24.000000      0.072130      3.302231
# max    36435.385542  2.681824e+03     27.000000      2.061261      3.699877
#
#        Temperature (C)_1
# count       23881.000000
# mean           10.273799
# std             0.354084
# min             9.598107
# 25%            10.038515
# 50%            10.179319
# 75%            10.451158
# max            11.582196

# %%
dst_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23881 entries, 0 to 23880
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       23881 non-null  float64
#  1   Step_Time(s)       23881 non-null  float64
#  2   Step_Index         23881 non-null  int64
#  3   Current(A)         23881 non-null  float64
#  4   Voltage(V)         23881 non-null  float64
#  5   Temperature (C)_1  23881 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Dynamic test profile at 20 degree celcius

# %%
dst_20=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-20\A1-008-DST-US06-FUDS-20-20120817.xlsx",sheet_name=2)

# %%
dst_20.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.008332      3.008332           1    0.000000    3.108637
# 1      8.014952      5.006227           2   -1.099776    2.891659
# 2     13.018221     10.009497           2   -1.099776    2.877501
# 3     18.022437     15.013712           2   -1.099957    2.864575
# 4     23.026696     20.017971           2   -1.099776    2.851957
# 5     28.035930     25.027205           2   -1.099957    2.839954
# 6     33.045322     30.036597           2   -1.099776    2.827950
# 7     38.051520     35.042795           2   -1.099957    2.815948
# 8     43.066605     40.057881           2   -1.099776    2.803944
# 9     48.077106     45.068381           2   -1.099776    2.791941
#
#    Temperature (C)_1
# 0          18.427523
# 1          18.444551
# 2          18.427523
# 3          18.489090
# 4          18.382978
# 5          18.458305
# 6          18.365955
# 7          18.427523
# 8          18.352194
# ...

# %%
dst_20.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  24992.000000  2.499200e+04  24992.000000  24992.000000  24992.000000
# mean   20478.506604  4.711195e+02     15.573944     -0.362114      3.195718
# std    10524.199546  4.800529e+02      6.722357      0.935984      0.229664
# min        3.008332  7.699193e-07      1.000000     -3.849713      1.898483
# 25%    10446.853748  1.524163e+02      8.000000     -0.862705      3.091094
# 50%    20715.938621  3.099327e+02     16.000000     -0.279794      3.208663
# 75%    30962.624857  5.888735e+02     24.000000      0.063971      3.315767
# max    37521.292897  2.867548e+03     27.000000      2.061054      3.732181
#
#        Temperature (C)_1
# count       24992.000000
# mean           20.023982
# std             0.324123
# min            18.321405
# 25%            19.784843
# 50%            19.990610
# 75%            20.230755
# max            21.150887

# %%
dst_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24992 entries, 0 to 24991
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       24992 non-null  float64
#  1   Step_Time(s)       24992 non-null  float64
#  2   Step_Index         24992 non-null  int64
#  3   Current(A)         24992 non-null  float64
#  4   Voltage(V)         24992 non-null  float64
#  5   Temperature (C)_1  24992 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Dynamic test profile at 25 degree celcius

# %%
dst_25=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-25\A1-007-DST-US06-FUDS-25-20120827.xlsx",sheet_name=2)

# %%
dst_25.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.053504      3.000204           1    0.000000    2.766393
# 1      8.061154      5.007273           2   -1.099373    2.501398
# 2     13.062293     10.008411           2   -1.099185    2.435226
# 3     18.071620     15.017739           2   -1.099373    2.340432
# 4     23.073773     20.019892           2   -1.099185    2.115448
# 5     24.301853     21.247971           2   -1.099373    1.998801
# 6     29.307341      5.004141           3    0.000000    2.460464
# 7     34.311587     10.008388           3    0.000000    2.474314
# 8     39.319818     15.016618           3    0.000000    2.482316
# 9     44.325095     20.021896           3    0.000000    2.486933
#
#    Temperature (C)_1
# 0          26.788187
# 1          26.818743
# 2          26.818743
# 3          26.713451
# 4          26.788187
# 5          26.893473
# 6          26.893473
# 7          26.713451
# 8          26.818743
# ...

# %%
dst_25.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  24469.000000  2.446900e+04  24469.000000  24469.000000  24469.000000
# mean   19726.353242  4.718362e+02     15.557767     -0.363447      3.204312
# std    10192.971787  5.018513e+02      6.710170      0.942908      0.211759
# min        3.053504  3.849596e-07      1.000000     -3.849407      1.937861
# 25%    10017.592323  1.497245e+02      8.000000     -0.867589      3.110487
# 50%    19958.708627  3.061075e+02     16.000000     -0.286440      3.214515
# 75%    29860.944817  5.805784e+02     24.000000      0.060672      3.311772
# max    36294.795004  3.070756e+03     27.000000      2.061261      3.699877
#
#        Temperature (C)_1
# count       24469.000000
# mean           27.256177
# std             0.252976
# min            26.427921
# 25%            27.090370
# 50%            27.216118
# 75%            27.385750
# max            28.366453

# %%
dst_25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24469 entries, 0 to 24468
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       24469 non-null  float64
#  1   Step_Time(s)       24469 non-null  float64
#  2   Step_Index         24469 non-null  int64
#  3   Current(A)         24469 non-null  float64
#  4   Voltage(V)         24469 non-null  float64
#  5   Temperature (C)_1  24469 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Dynamic test profile at 30 degree celcius

# %%
dst_30=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-30\A1-007-DST-US06-FUDS-30-20120820.xlsx",sheet_name=2)

# %%
dst_30.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.004871      3.004871           1    0.000000    3.075400
# 1      8.011347      5.006164           2   -1.099373    2.888580
# 2     13.017574     10.012391           2   -1.099373    2.876269
# 3     18.023831     15.018647           2   -1.099373    2.864882
# 4     23.027999     20.022816           2   -1.099373    2.853494
# 5     28.032410     25.027227           2   -1.099373    2.842414
# 6     33.039675     30.034492           2   -1.099373    2.831334
# 7     38.041781     35.036597           2   -1.099373    2.819946
# 8     43.043244     40.038061           2   -1.099373    2.808558
# 9     48.043298     45.038114           2   -1.099560    2.796555
#
#    Temperature (C)_1
# 0          31.391201
# 1          31.242373
# 2          31.391201
# 3          31.421654
# 4          31.496058
# 5          31.421654
# 6          31.421654
# 7          31.465605
# 8          31.465605
# ...

# %%
dst_30.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  24598.000000  2.459800e+04  24598.000000  24598.000000  24598.000000
# mean   19621.906470  4.721762e+02     15.567973     -0.364780      3.206956
# std    10170.231343  5.126144e+02      6.716462      0.942931      0.203930
# min        3.004871  3.849596e-07      1.000000     -3.849407      1.949556
# 25%     9938.020160  1.497872e+02      8.000000     -0.871909      3.116026
# 50%    19831.893588  3.053628e+02     16.000000     -0.297146      3.217592
# 75%    29711.598095  5.757773e+02     24.000000      0.049966      3.312695
# max    36178.975170  3.143676e+03     27.000000      2.061261      3.696491
#
#        Temperature (C)_1
# count       24598.000000
# mean           32.004251
# std             0.234140
# min            31.174595
# 25%            31.850952
# 50%            31.952837
# 75%            32.128143
# max            33.004131

# %%
dst_30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24598 entries, 0 to 24597
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       24598 non-null  float64
#  1   Step_Time(s)       24598 non-null  float64
#  2   Step_Index         24598 non-null  int64
#  3   Current(A)         24598 non-null  float64
#  4   Voltage(V)         24598 non-null  float64
#  5   Temperature (C)_1  24598 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Dynamic test profile at 50 degree celcius

# %%
dst_50=pd.read_excel(r"C:\Users\jaiku\PycharmProjects\Assignments\A123 battery\Dynamic Profiles\DST-US06-FUDS-50\A1-007-DST-US06-FUDS-50-20120824.xlsx",sheet_name=2)

# %%
dst_50.head(10)
# Out:
#    Test_Time(s)  Step_Time(s)  Step_Index  Current(A)  Voltage(V)  \
# 0      3.007451      3.007451           1    0.000000    2.775626
# 1      8.012196      5.004451           2   -1.099373    2.564185
# 2     13.012202     10.004457           2   -1.099373    2.523558
# 3     18.014646     15.006900           2   -1.099373    2.473083
# 4     23.021725     20.013979           2   -1.099373    2.404141
# 5     28.021949     25.014203           2   -1.099185    2.257025
# 6     30.994169     27.986424           2   -1.099185    1.999724
# 7     35.996811      5.001098           3    0.000000    2.367208
# 8     41.000069     10.004355           3    0.000000    2.385059
# 9     46.000322     15.004608           3    0.000000    2.393369
#
#    Temperature (C)_1
# 0          50.789497
# 1          50.789497
# 2          50.789497
# 3          50.746269
# 4          50.879433
# 5          50.952637
# 6          50.746269
# 7          50.836208
# 8          50.866188
# ...

# %%
dst_50.describe()
# Out:
#        Test_Time(s)  Step_Time(s)    Step_Index    Current(A)    Voltage(V)  \
# count  24763.000000  2.476300e+04  24763.000000  24763.000000  24763.000000
# mean   19197.121372  4.804346e+02     15.652263     -0.367141      3.214068
# std    10034.610605  5.380568e+02      6.695618      0.947778      0.195042
# min        3.007451  3.849596e-07      1.000000     -3.849407      1.926166
# 25%     9617.456118  1.515973e+02      8.000000     -0.880455      3.126183
# 50%    19349.539252  3.072322e+02     16.000000     -0.311609      3.226826
# 75%    29076.097827  5.734703e+02     24.000000      0.034939      3.320697
# max    35582.345606  3.301138e+03     27.000000      2.061261      3.709726
#
#        Temperature (C)_1
# count       24763.000000
# mean           52.430148
# std             0.297348
# min            50.746269
# 25%            52.255783
# 50%            52.425720
# 75%            52.598465
# max            53.452240

# %%
dst_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24763 entries, 0 to 24762
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Time(s)       24763 non-null  float64
#  1   Step_Time(s)       24763 non-null  float64
#  2   Step_Index         24763 non-null  int64
#  3   Current(A)         24763 non-null  float64
#  4   Voltage(V)         24763 non-null  float64
#  5   Temperature (C)_1  24763 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 MB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.ticker import ScalarFormatter
from matplotlib.gridspec import GridSpec

# Set style for better visualization
plt.style.use('seaborn-v0_8-whitegrid')

# Define color map for temperatures
temp_colors = {
    '-10': '#0033A0',  # Deep blue
    '0': '#0066CC',    # Blue
    '10': '#3399FF',   # Light blue
    '20': '#66CC00',   # Green
    '25': '#FFCC00',   # Yellow
    '30': '#FF9900',   # Orange
    '40': '#FF6600',   # Dark orange
    '50': '#CC0000'    # Red
}

# List of all temperature datasets
temp_datasets = {
    '-10': low_curr_ocv_minus_10,
    '0': low_curr_ocv_0,
    '10': low_curr_ocv_10,
    '20': low_curr_ocv_20,
    '25': low_curr_ocv_25,
    '30': low_curr_ocv_30,
    '40': low_curr_ocv_40,
    '50': low_curr_ocv_50
}

# %% [markdown]
# # 1. Charge Capacity vs Cycle Function
# ### This plot shows how the battery's charge capacity changes over cycles at different temperatures:

# %%
def plot_charge_capacity_vs_cycle(datasets, temp_colors):
    """
    Plot charge capacity vs cycle for different temperatures.
    
    Parameters:
    -----------
    datasets : dict
        Dictionary with temperature as keys and dataframes as values
    temp_colors : dict
        Dictionary with temperature as keys and color codes as values
    """
    plt.figure(figsize=(12, 8))
    
    for temp, df in datasets.items():
        # Group by cycle and get max charge capacity for each cycle
        cycle_data = df.groupby('Cycle_Index')['Discharge_Capacity(Ah)'].max().reset_index()
        
        plt.plot(cycle_data['Cycle_Index'], cycle_data['Discharge_Capacity(Ah)'], 
                 marker='o', linestyle='-', label=f'{temp}°C', color=temp_colors[temp])
    
    plt.title('Disharge Capacity vs Cycle at Different Temperatures', fontsize=16)
    plt.xlabel('Cycle Number', fontsize=14)
    plt.ylabel('Discharge Capacity (Ah)', fontsize=14)
    plt.grid(True)
    plt.legend(fontsize=12, title='Temperature (°C)')
    plt.tight_layout()
    plt.rcParams['xtick.labelsize'] = 14  # X-axis tick labels
    plt.rcParams['ytick.labelsize'] = 14  # Y-axis tick labels
    # Save figure
    plt.savefig('discharge_capacity_vs_cycle.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_charge_capacity_vs_cycle(temp_datasets, temp_colors)

# %% [markdown]
# # Understanding Battery Performance at Different Temperatures
#
# ## What This Plot Shows
#
# This graph illustrates how temperature affects a lithium-ion battery's discharge capacity (specifically an A123 battery). Though we're only seeing data from a single battery cycle, the plot reveals an important relationship between temperature and battery performance.
#
# ## Simple Explanation
#
# ### What is Discharge Capacity?
# Discharge capacity (measured in Ampere-hours or Ah) is essentially how much energy a battery can deliver before running out. Think of it like the size of your gas tank - a higher capacity means your device runs longer before needing a recharge.
#
# ### Key Observations
# Looking at the data points on the graph:
#
# - **Warm batteries perform better**: The batteries at 40°C and 50°C (red and orange dots) have the highest discharge capacity (around 1.080 Ah)
# - **Cold batteries perform worse**: The battery at -10°C (darkest blue dot) has the lowest capacity (around 1.042 Ah)
# - **Clear temperature pattern**: As temperature increases from cold to warm, the battery capacity consistently increases
#
# ### Real-World Impact
# This 3-4% difference in capacity might seem small, but imagine:
# - Your phone dying 3-4% faster in cold weather
# - Your electric car's range dropping noticeably in winter
# - Your laptop battery not lasting as long when used outdoors in cold temperatures
#
# ## Engineering Insights
#
# ### Why Temperature Affects Batteries
# Temperature impacts how quickly chemical reactions can occur inside the battery:
#
# 1. **Cold temperatures** slow down the movement of ions (charged particles) through the battery's electrolyte, creating higher internal resistance and reducing available capacity
#
# 2. **Warm temperatures** increase ion mobility and reduce internal resistance, allowing more of the battery's stored energy to be accessible
#
# ### Temperature Management Considerations
#
# - **Optimal operating range**: This data suggests the A123 battery performs best at higher temperatures (30-50°C), but...
#
# - **Long-term effects**: While not shown in this single-cycle data, sustained high temperatures accelerate battery degradation and shorten overall lifespan
#
# - **Design implications**: Engineers must balance:
#   - Thermal management systems that keep batteries warm in cold weather
#   - Cooling systems that prevent overheating in hot conditions
#   - Insulation that maintains consistent temperature
#
# ### Application Insights
#
# - **Electric vehicles**: Cold weather range reduction is a real concern, which is why many EVs have battery heating systems
#
# - **Consumer electronics**: This explains why phones shut down faster in very cold weather, even when showing battery remaining
#
# - **Performance/longevity trade-off**: While a 50°C battery delivers more energy initially, operating at such high temperatures would significantly reduce its lifetime
#
# ## Key Takeaway
#
# Battery performance is temperature-dependent, with warmer temperatures generally providing better immediate performance but potentially faster degradation over time. Understanding this relationship helps engineers design better battery systems and helps users understand why their battery-powered devices behave differently in various weather conditions.

# %% [markdown]
# # 2. dV/dt vs Capacity Function
# ### This plot helps identify phase transitions during charging:

# %%
def plot_dvdt_vs_capacity(datasets, temp_colors):
    """
    Plot dV/dt vs capacity for different temperatures.
    
    Parameters:
    -----------
    datasets : dict
        Dictionary with temperature as keys and dataframes as values
    temp_colors : dict
        Dictionary with temperature as keys and color codes as values
    """
    fig = plt.figure(figsize=(16, 20))
    gs = GridSpec(2, 1, height_ratios=[1, 1])
    
    # Plot for charging
    ax1 = fig.add_subplot(gs[0])
    for temp, df in datasets.items():
        # Filter for charging data (Current > 0)
        charge_data = df[df['Current(A)'] > 0.1].copy()
        if not charge_data.empty:
            ax1.scatter(charge_data['Charge_Capacity(Ah)'], charge_data['dV/dt(V/s)'], 
                      s=10, alpha=0.6, label=f'{temp}°C', color=temp_colors[temp])
    
    ax1.set_title('dV/dt vs Charge Capacity', fontsize=26)
    ax1.set_ylabel('dV/dt (V/s)', fontsize=24)
    ax1.grid(True)
    ax1.legend(fontsize=20, title='Temperature (°C)')
    
    
    
    
    plt.tight_layout()
    plt.rcParams['xtick.labelsize'] = 14  # X-axis tick labels
    plt.rcParams['ytick.labelsize'] = 14  # Y-axis tick labels
    # Save figure
    plt.savefig('dvdt_vs_capacity.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_dvdt_vs_capacity(temp_datasets, temp_colors)

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharex=True, sharey=True)
axes = axes.flatten()

for i, (temp, df) in enumerate(sorted(temp_datasets.items())):
    ax = axes[i]
    # Filter data (remove extreme outliers)
    charge_data = df[(df['Current(A)'] > 0.1) & (abs(df['dV/dt(V/s)']) < 0.005)]
    
    # Plot each temperature in its own subplot with larger points
    ax.scatter(charge_data['Charge_Capacity(Ah)'], charge_data['dV/dt(V/s)'], 
              color=temp_colors[temp], alpha=0.7, s=15)
    
    ax.set_title(f'Temperature: {temp}°C')
    ax.grid(True, alpha=0.3)
    
    # Only add axis labels on the outer plots
    if i >= 4:  # Bottom row
        ax.set_xlabel('Charge Capacity (Ah)')
    if i % 4 == 0:  # Left column
        ax.set_ylabel('dV/dt (V/s)')

plt.suptitle('dV/dt vs Charge Capacity by Temperature', fontsize=20)
plt.tight_layout()

# %% [markdown]
# # Understanding Battery Charging Behavior at Different Temperatures
#
# ## What We're Looking At
#
# This set of graphs shows how quickly a battery's voltage changes (dV/dt) during charging at eight different temperatures, from very cold (-10°C) to quite hot (50°C). Each small graph represents one temperature condition, and all eight together tell an interesting story about how batteries behave.
#
# ## The Basic Idea in Simple Terms
#
# When you charge a battery, its voltage doesn't increase at a steady rate throughout the entire process. Instead, the voltage sometimes changes quickly and sometimes changes slowly, depending on what's happening inside. These graphs track that rate of change (dV/dt) as the battery fills up (charge capacity).
#
# ## Key Observations Anyone Can Understand
#
# ### The Dramatic Difference at 25°C (Room Temperature)
#
# The most striking feature is in the bottom-left graph (25°C). This shows:
#
# - A tall column of dots at the very beginning of charging
# - These dots show that when a room-temperature battery first starts charging, its voltage rises very rapidly
# - As charging continues (moving right on the graph), this rapid rise quickly settles down to near-zero
#
# ### Cold vs. Warm Temperatures
#
# - At cold temperatures (-10°C, 0°C): Very few data points and minimal voltage changes
# - At moderate temperatures (10°C, 20°C): More activity, but still relatively calm
# - At high temperatures (30°C, 40°C, 50°C): Activity concentrated at the beginning of charging, but not nearly as dramatic as at 25°C
#
# ### The "Sweet Spot" of Room Temperature
#
# This data strongly suggests that 25°C (about 77°F) – typical room temperature – creates ideal conditions for battery charging. The chemical reactions inside the battery appear most responsive at this temperature.
#
# ## Real-World Connections
#
# This explains several everyday experiences with batteries:
#
# - Why your devices might charge better when they're at room temperature
# - Why very cold phones charge slowly and seem to have less capacity
# - Why manuals often recommend charging devices at room temperature for best results
#
# Think of it like trying to pour honey: when it's cold, it flows very slowly (low dV/dt); when it's at room temperature, it flows nicely; when it's too hot, it might flow too quickly but less controllably.
#
# ## Engineering Insights
#
# For those interested in the technical aspects:
#
# 1. **Phase transitions**: The high dV/dt values at the beginning of charging at 25°C likely represent a phase transition in the battery materials, where lithium ions begin moving into the graphite anode.
#
# 2. **Temperature-dependent kinetics**: Chemical reactions in batteries are highly temperature-dependent. The data suggests that 25°C provides optimal energy for the charging reactions, allowing them to proceed effectively without excessive resistance (cold temperatures) or side reactions (hot temperatures).
#
# 3. **Charging algorithm implications**: Battery management systems track these voltage changes to determine optimal charging rates. This data explains why charging algorithms might apply different profiles at different temperatures.
#
# 4. **Design considerations**: Engineers designing battery systems must account for these temperature effects, perhaps by including heating elements for cold-weather operation or cooling systems for hot environments.
#
# 5. **Peak dV/dt as diagnostic tool**: The height and shape of the initial dV/dt peak could potentially serve as a diagnostic tool for battery health assessment.
#
# ## Why This Matters
#
# This visualization helps explain why:
#
# - Electric vehicles have battery thermal management systems
# - Your phone might warn you when it's too hot or cold to charge properly
# - Battery performance varies with the seasons
# - Manufacturers recommend specific charging conditions
#
# The data reveals that batteries aren't simple storage containers but complex electrochemical systems whose behavior changes dramatically with temperature – with room temperature appearing to be the "Goldilocks zone" where charging behavior is most dynamic and efficient.

# %% [markdown]
# # 3  Capacity vs Voltage Function ( charging capacity )
# ### This creates voltage profiles for each temperature, showing how voltage varies with capacity during charge:

# %%
def plot_capacity_vs_voltage(datasets, temp_colors):
    """
    Plot capacity vs voltage for both charging at different temperatures.
    
    Parameters:
    -----------
    datasets : dict
        Dictionary with temperature as keys and dataframes as values
    temp_colors : dict
        Dictionary with temperature as keys and color codes as values
    """
    fig,ax1 = plt.subplots(1, 1, figsize=(18, 10))
    
    # Plot for charging
    for temp, df in datasets.items():
        # Filter for charging data and select the first cycle for clarity
        charge_data = df[(df['Current(A)'] > 0.1) & (df['Cycle_Index'] == 1)].copy()
        if not charge_data.empty:
            ax1.plot(charge_data['Charge_Capacity(Ah)'], charge_data['Voltage(V)'], 
                     label=f'{temp}°C', color=temp_colors[temp], linewidth=2)
    
    ax1.set_title('Charge Capacity vs Voltage', fontsize=16)
    ax1.set_xlabel('Charge Capacity (Ah)', fontsize=14)
    ax1.set_ylabel('Voltage (V)', fontsize=14)
    ax1.grid(True)
    ax1.legend(fontsize=12, title='Temperature (°C)')
    
    
    
    plt.tight_layout()
    plt.rcParams['xtick.labelsize'] = 14  # X-axis tick labels
    plt.rcParams['ytick.labelsize'] = 14  # Y-axis tick labels
    # Save figure
    plt.savefig('capacity_vs_voltage.png', dpi=300, bbox_inches='tight')
    plt.show()
plot_capacity_vs_voltage(temp_datasets, temp_colors)

# %% [markdown]
# # Understanding Battery Charging Behavior: Voltage vs. Capacity
#
# ## What This Graph Shows
#
# This graph illustrates how a battery's voltage changes as it charges at different temperatures. The horizontal axis shows the charge capacity (how "full" the battery is), while the vertical axis shows the voltage (electrical pressure) of the battery.
#
# ## Key Features for Anyone to Understand
#
# ### The Curious Case of Temperature Effects
#
# The most striking feature is the dramatic difference between charging behaviors at different temperatures:
#
# - **The yellow curve (25°C/room temperature)** shows a complete charging profile. This is what we see most clearly - a smooth curve that starts around 3.1V when empty and gradually rises to about 3.6V when full.
#
# - **The blue line (likely -10°C or 0°C)** shows a completely different pattern - a flat line at about 3.6V. This suggests cold batteries behave differently than room-temperature ones.
#
# - **The initial spike** at the very beginning shows a momentary voltage jump when charging first starts.
#
# ### What This Means in Everyday Terms
#
# This is similar to filling different containers with water:
#
# - The yellow curve (room temperature battery) is like filling a vase that gets wider toward the top - it fills quickly at first (voltage rises rapidly), then more slowly as you reach the top (voltage levels off).
#
# - The blue flat line (cold battery) is like filling a container with a completely different shape - the water level (voltage) behaves differently as you add more water (charge).
#
# ## Practical Implications
#
# 1. **Temperature matters enormously** for how batteries charge. This explains why:
#    - Your phone might charge differently in winter vs. summer
#    - Electric car charging speeds vary with weather conditions
#    - Batteries often perform best at room temperature
#
# 2. **Voltage doesn't increase evenly** as a battery charges. This is why:
#    - Devices sometimes show battery percentage increasing at different rates
#    - Fast charging typically works best when batteries are partially empty
#    - Charging slows down as batteries approach full capacity
#
# ## Engineering Insights
#
# For those interested in the technical aspects:
#
# 1. **Electrochemical staging**: The gradual slope of the 25°C curve shows lithium-ion intercalation stages in the graphite anode. As the battery charges, lithium ions fill available sites in the graphite in distinct phases, creating the characteristic voltage profile.
#
# 2. **Temperature-dependent kinetics**: Cold temperatures significantly increase internal resistance and slow down ion diffusion, explaining the flat profile at low temperatures. This resistance causes energy loss as heat and reduces charging efficiency.
#
# 3. **State of charge estimation**: Battery management systems use these voltage curves as references for estimating how full a battery is. The distinctive shape at room temperature provides clear markers for different charge states.
#
# 4. **Charging protocol design**: Engineers must account for these temperature effects when designing charging algorithms. The optimal charging protocol for 25°C would be inappropriate and potentially damaging at -10°C or 50°C.
#
# 5. **Cell design implications**: Battery chemistry and physical construction significantly influence the shape of these curves. Cell designers analyze these profiles when developing new battery formulations.
#
# ## Why This Matters
#
# This graph helps explain why:
#
# - Manufacturers specify operating temperature ranges for batteries
# - Electric vehicles have sophisticated battery thermal management systems
# - Quick-charging technologies can only work within specific temperature windows
# - Your devices might warn you when they're too hot or cold to charge properly
#
# The data confirms that lithium-ion batteries operate most predictably and efficiently at room temperature, with significant behavioral changes at temperature extremes. This fundamental characteristic affects everything from smartphone charging to electric grid storage systems.

# %% [markdown]
# # Understanding the Overlapping Lines in the Battery Charging Graph
#
# Yes, there is significant overlap between some of the temperature lines in this graph, which is an important observation! This overlap reveals crucial insights about battery charging behavior.
#
# ## Where the Overlapping Occurs
#
# Looking closely at the graph:
#
# 1. **Cold temperature lines overlap** - The blue lines (representing -10°C, 0°C, and 10°C) appear to run almost on top of each other at approximately 3.6V across much of the charging range. This suggests very similar voltage behavior during charging at these cold temperatures.
#
# 2. **Initial spike overlap** - At the very beginning of charging (near 0.0 Ah), several temperature lines start at similar points before diverging.
#
# 3. **Some warmer temperature lines** may also overlap in certain regions, though the yellow line (25°C) is most distinct.
#
# ## What This Overlap Tells Us
#
# This overlapping pattern reveals something fascinating about batteries:
#
# 1. **Temperature "bands" of similar behavior** - Batteries appear to behave in similar ways within certain temperature ranges. Cold temperatures (-10°C to 10°C) produce one type of behavior, while room temperature produces another.
#
# 2. **Threshold effects** - Rather than gradually changing behavior with each degree of temperature change, batteries seem to have threshold temperatures where their behavior changes more dramatically.
#
# 3. **Room temperature uniqueness** - The most distinct line is the yellow line (25°C/room temperature), showing this temperature creates unique charging behavior compared to both colder and hotter temperatures.
#
# This is like how water behaves similarly as a liquid between 1°C and 99°C, but dramatically changes behavior below 0°C (ice) or above 100°C (steam). Battery charging behavior appears to have similar "state changes" at certain temperature thresholds.
#
# ## Engineering Significance
#
# The overlapping lines have important implications:
#
# 1. **Battery management simplification** - Engineers can develop charging algorithms for temperature "bands" rather than needing unique profiles for every possible temperature.
#
# 2. **Critical temperature thresholds** - The data suggests key temperature boundaries where battery behavior changes significantly, which is crucial for thermal management system design.
#
# 3. **Optimal charging window** - The distinct profile at 25°C reinforces that room temperature represents an ideal charging condition, with behavior becoming more problematic (and more similar) at temperature extremes.
#
# 4. **Reduced data resolution at extremes** - When designing battery systems, engineers might need fewer sensors or calculations to manage cold-temperature charging but more precise controls around room temperature.
#
# The overlapping lines aren't an error in the data or visualization—they're revealing important physical properties about how lithium-ion batteries respond to temperature during charging.

# %% [markdown]
# ###  Capacity vs Voltage Function ( discharging capacity )

# %%
def plot_corrected_discharge_curves(datasets, temp_colors):
    """
    Corrected discharge plotting function using the right current threshold
    """
    
    plt.figure(figsize=(14, 8))
    
    for temp, df in datasets.items():
        print(f"Processing {temp}°C...")
        
        # CORRECTED: Use -0.01 threshold instead of -0.1
        # Since your discharge current is exactly -0.050A
        discharge_data = df[
            (df['Current(A)'] < -0.01) &  # This will catch -0.050A
            (df['Discharge_Capacity(Ah)'] > 0) &  # Only positive discharge capacity
            (df['Cycle_Index'] == 1)  # First cycle only
        ].copy()
        
        print(f"  Found {len(discharge_data)} discharge data points")
        
        if len(discharge_data) > 10:
            # Sort by discharge capacity for smooth curve
            discharge_data = discharge_data.sort_values('Discharge_Capacity(Ah)')
            
            # Plot the discharge curve
            plt.plot(discharge_data['Discharge_Capacity(Ah)'], 
                    discharge_data['Voltage(V)'], 
                    label=f'{temp}°C', 
                    color=temp_colors[temp], 
                    linewidth=2.5, 
                    alpha=0.8)
            
            print(f"  Successfully plotted curve for {temp}°C")
            print(f"    Capacity range: {discharge_data['Discharge_Capacity(Ah)'].min():.3f} to {discharge_data['Discharge_Capacity(Ah)'].max():.3f} Ah")
            print(f"    Voltage range: {discharge_data['Voltage(V)'].min():.3f} to {discharge_data['Voltage(V)'].max():.3f} V")
    
    plt.title('Battery Discharge Curves by Temperature (Corrected)', fontsize=16)
    plt.xlabel('Discharge Capacity (Ah)', fontsize=14)
    plt.ylabel('Voltage (V)', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=12, title='Temperature (°C)', loc='upper right')
    
    # Set appropriate axis limits based on your data
    plt.xlim(0, 1.1)  # From 0 to slightly above max capacity
    plt.ylim(2.5, 4.0)  # Typical Li-ion voltage range
    
    plt.tight_layout()
    plt.savefig('corrected_discharge_curves.png', dpi=300, bbox_inches='tight')
    plt.show()

# Run the corrected function
plot_corrected_discharge_curves(temp_datasets, temp_colors)
# Out:
# Processing -10°C...
#   Found 15244 discharge data points
#   Successfully plotted curve for -10°C
#     Capacity range: 0.000 to 1.060 Ah
#     Voltage range: 2.000 to 3.519 V
# Processing 0°C...
#   Found 15215 discharge data points
#   Successfully plotted curve for 0°C
#     Capacity range: 0.000 to 1.058 Ah
#     Voltage range: 2.000 to 3.510 V
# Processing 10°C...
#   Found 15006 discharge data points
#   Successfully plotted curve for 10°C
#     Capacity range: 0.000 to 1.042 Ah
#     Voltage range: 2.000 to 3.476 V
# Processing 20°C...
#   Found 15319 discharge data points
#   Successfully plotted curve for 20°C
#     Capacity range: 0.000 to 1.065 Ah
#     Voltage range: 2.000 to 3.500 V
# Processing 25°C...
#   Found 15314 discharge data points
#   Successfully plotted curve for 25°C
#     Capacity range: 0.000 to 1.064 Ah
#     Voltage range: 2.000 to 3.497 V
# Processing 30°C...
#   Found 15431 discharge data points
#   Successfully plotted curve for 30°C
# ...

# %% [markdown]
# # Understanding the Battery Discharge Graph: A Vertical Line Mystery
#
# ## What We're Looking At
#
# This graph shows the relationship between "Discharge Capacity" (x-axis) and "Voltage" (y-axis) for a battery at different temperatures. However, there's something unusual happening - instead of curves extending across the graph, we see only a vertical line at zero discharge!
#
# ## Explaining What We See
#
# ### The Vertical Line Phenomenon
#
# The most striking feature is that there's only a single vertical line at the 0.00 mark on the x-axis, with voltage values ranging from about 3.1V to 3.9V. The different colors represent different temperatures from -10°C (coldest/blue) to 50°C (warmest/red).
#
# ### What This Actually Means
#
# This vertical line shows us the **starting voltage** of the battery at different temperatures **before any discharge has occurred**. Essentially, we're seeing:
#
# 1. Cold batteries (-10°C, blue at top) start at a higher voltage (around 3.9V)
# 2. As temperature increases, the starting voltage decreases
# 3. The warmest batteries (50°C, red) start at a lower voltage (around 3.1-3.2V)
#
# ## Making Sense of This for Non-Engineers
#
# Think of this like measuring the water pressure in hoses at different temperatures before turning on the water. We've measured the pressure (voltage), but we haven't actually let any water flow (discharge) yet.
#
# This is useful information, but it's only showing us the starting point. It's like seeing how high different runners position themselves in starting blocks before a race begins, without seeing the actual race.
#
# ### What's Missing?
#
# A typical discharge graph would show lines extending to the right, displaying how voltage drops as the battery discharges (similar to how water pressure might drop as a tank empties). Here, we only see the starting point.
#
# ## Why Temperature Affects Starting Voltage
#
# Temperature affects the chemical reactions inside batteries:
#
# - **Cold batteries** have slower internal chemical reactions, which creates a higher initial voltage reading (though they typically have worse performance overall)
# - **Warm batteries** have more active internal chemistry, resulting in lower initial voltage but often better actual performance
#
# This is similar to how cold honey appears thicker and sits higher in a container, while warm honey flows more easily but settles to a lower level.
#
# ## Engineering Insights
#
# From an engineering perspective, this plot reveals several important phenomena:
#
# 1. **Temperature-dependent open circuit voltage (OCV)**: The data confirms that battery resting voltage is strongly temperature-dependent, with an approximately 0.8V difference between coldest and warmest conditions.
#
# 2. **Inverse temperature-voltage relationship**: The consistent pattern of higher voltages at lower temperatures reflects the thermodynamic properties of lithium-ion cells, specifically how temperature affects the Nernst equation governing electrochemical potentials.
#
# 3. **Data collection methodology**: This appears to be from a test where the battery's voltage was measured at different temperatures before discharge testing began. This is standard practice to establish baseline conditions.
#
# 4. **Visualization limitations**: The narrow x-axis range (-0.05 to +0.05 Ah) suggests either minimal discharge occurred or the graph is zoomed to show only the initial voltage state.
#
# 5. **Diagnostic value**: These initial voltage differences provide a calibration reference that engineers use when designing battery management systems to accurately estimate state of charge across temperature ranges.
#
# ## Practical Applications
#
# Understanding how temperature affects battery voltage helps explain:
#
# - Why your phone might show different battery percentages in cold versus warm environments
# - Why electric vehicles provide different range estimates based on temperature
# - Why battery testers and diagnostic tools often ask for temperature information
#
# ## What Would Make This Graph More Informative
#
# For a complete picture, we would need to see:
# - The full discharge curves extending to the right
# - How quickly voltage drops during discharge at each temperature
# - The total capacity achieved at each temperature
#
# This would show not just how batteries start at different temperatures, but how they perform throughout their discharge cycle.

# %% [markdown]
# Okay, here's a concise Markdown version of your battery discharge analysis:
#
# ## Understanding Battery Discharge Behavior: Complete Temperature Analysis
#
# This visualization displays A123 battery discharge curves across various temperatures, showing voltage decrease as energy is delivered. The plot includes both the complete discharge profiles and the initial open-circuit voltages for each thermal condition.
#
# ---
#
# ### Detailed Temperature-by-Temperature Analysis
#
# * **-10°C (Dark Blue):** Starts highest (~3.9V) but drops steeply due to increased internal resistance ("voltage sag"). Delivers ~0.95Ah, terminating at ~2.65V. Classic cold-weather issue: high initial voltage, reduced actual energy.
# * **0°C (Medium Blue):** Starts ~3.85V with a more gradual decline than -10°C. Middle portion shows more stable voltage. Delivers ~0.98Ah. A critical threshold for battery management adjustments.
# * **10°C (Light Blue):** Starts ~3.8V with a smoother, more linear voltage drop. Delivers ~1.0Ah with better voltage stability. Near-normal efficiency for many devices.
# * **20°C (Green):** Starts ~3.75V, showing excellent voltage stability and minimal sag. Delivers ~1.05Ah. Typical reliable indoor performance.
# * **25°C (Yellow):** Starts ~3.7V, representing the **gold standard** with exceptional voltage stability and the most gradual decline. Delivers ~1.06Ah. Performance baseline for manufacturer ratings.
# * **30°C (Orange):** Starts ~3.68V, maintains good stability. Delivers slightly higher capacity (~1.07Ah) than 25°C due to increased ion mobility, but subtle voltage profile changes begin.
# * **40°C (Dark Orange):** Starts ~3.65V, delivering the highest capacity in this range (~1.08Ah). Voltage profile shows early indicators of thermal stress despite excellent immediate performance.
# * **50°C (Red):** Starts lowest (~3.6V) but delivers the peak capacity (~1.09Ah). Illustrates complex thermodynamics at elevated temperatures; indicates practical upper limit for beneficial temperature effects due to accelerated aging if sustained.
#
# ---
#
# ### Synthesis: Understanding the Complete Temperature Story
#
# The relationship between temperature and A123 battery performance is a complex optimization curve:
# * **Cold temperatures** increase internal resistance, reducing capacity and voltage stability.
# * **Warm temperatures** improve immediate performance (capacity, lower resistance) but introduce thermal stress and long-term degradation risks.
# * The **optimal balance** for A123 cells appears to be **25°C to 30°C**.
#
# This comprehensive analysis highlights the critical role of **thermal management systems** in maintaining batteries within their ideal operational window for optimal performance, efficiency, and longevity.

# %%
def plot_charge_capacity_bar_graph(datasets, temp_colors):
    """
    Create a bar graph showing discharge capacity at different temperatures.
    
    This visualization makes temperature-based comparisons much clearer
    than the original line plot, especially when we're primarily interested
    in comparing performance across temperatures rather than cycle progression.
    
    Parameters:
    -----------
    datasets : dict
        Dictionary with temperature as keys and dataframes as values
    temp_colors : dict
        Dictionary with temperature as keys and color codes as values
    """
    
    # Step 1: Extract capacity data for each temperature
    # We'll focus on the maximum capacity achieved at each temperature
    temperatures = []  # List to store temperature values for x-axis
    capacities = []    # List to store corresponding capacity values
    colors = []        # List to store colors for each bar
    
    # Process each temperature dataset
    for temp, df in datasets.items():
        # Get the maximum discharge capacity for this temperature
        # Using the same logic as before: group by cycle and take max
        cycle_data = df.groupby('Cycle_Index')['Discharge_Capacity(Ah)'].max()
        
        if not cycle_data.empty:
            # For bar graph, we typically want one representative value per temperature
            # Using the maximum capacity achieved across all cycles at this temperature
            max_capacity = cycle_data.max()
            
            # Store the data for plotting
            temperatures.append(float(temp))  # Convert to float for proper sorting
            capacities.append(max_capacity)
            colors.append(temp_colors[temp])
    
    # Step 2: Sort data by temperature for logical presentation
    # This creates a natural progression from cold to hot temperatures
    sorted_indices = sorted(range(len(temperatures)), key=lambda i: temperatures[i])
    temperatures = [temperatures[i] for i in sorted_indices]
    capacities = [capacities[i] for i in sorted_indices]
    colors = [colors[i] for i in sorted_indices]
    
    # Step 3: Create the bar graph
    plt.figure(figsize=(12, 8))
    
    # Create bars with custom colors for each temperature
    bars = plt.bar(range(len(temperatures)), capacities, 
                   color=colors, alpha=0.8, edgecolor='black', linewidth=1.5)
    
    # Step 4: Customize the appearance for maximum clarity
    
    # Set x-axis labels to show actual temperatures
    plt.xticks(range(len(temperatures)), [f'{temp}°C' for temp in temperatures], fontsize=12)
    
    # Add value labels on top of each bar for precise reading
    for i, (bar, capacity) in enumerate(zip(bars, capacities)):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
                f'{capacity:.3f}', ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    # Step 5: Add comprehensive labeling and styling
    plt.title('Battery Discharge Capacity by Temperature\n(Bar Graph Comparison)', fontsize=16, fontweight='bold')
    plt.xlabel('Temperature (°C)', fontsize=14)
    plt.ylabel('Maximum Discharge Capacity (Ah)', fontsize=14)
    
    # Add a subtle grid for easier value reading
    plt.grid(axis='y', alpha=0.3, linestyle='--')
    
    # Ensure y-axis starts from a reasonable minimum to highlight differences
    plt.ylim(bottom=min(capacities) * 0.98)  # Start slightly below minimum value
    
    # Step 6: Add annotations to highlight key insights
    
    # Find and annotate the maximum and minimum values
    max_idx = capacities.index(max(capacities))
    min_idx = capacities.index(min(capacities))
    
    # Annotate the highest performing temperature
    plt.annotate(f'Peak Performance\n{capacities[max_idx]:.3f} Ah', 
                xy=(max_idx, capacities[max_idx]), 
                xytext=(max_idx, capacities[max_idx] + 0.01),
                arrowprops=dict(arrowstyle='->', color='green', lw=2),
                fontsize=11, ha='center', color='green', fontweight='bold',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='lightgreen', alpha=0.7))
    
    # Annotate the lowest performing temperature
    plt.annotate(f'Lowest Capacity\n{capacities[min_idx]:.3f} Ah', 
                xy=(min_idx, capacities[min_idx]), 
                xytext=(min_idx, capacities[min_idx] - 0.015),
                arrowprops=dict(arrowstyle='->', color='red', lw=2),
                fontsize=11, ha='center', color='red', fontweight='bold',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='lightcoral', alpha=0.7))
    
    # Step 7: Enhance readability with better formatting
    plt.rcParams['xtick.labelsize'] = 12
    plt.rcParams['ytick.labelsize'] = 12
    
    plt.tight_layout()
    
    # Save with descriptive filename
    plt.savefig('discharge_capacity_bar_graph.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # Step 8: Print summary statistics for additional insights
    print("\n" + "="*50)
    print("BATTERY CAPACITY ANALYSIS SUMMARY")
    print("="*50)
    print(f"Temperature range tested: {min(temperatures)}°C to {max(temperatures)}°C")
    print(f"Highest capacity: {max(capacities):.3f} Ah at {temperatures[max_idx]}°C")
    print(f"Lowest capacity: {min(capacities):.3f} Ah at {temperatures[min_idx]}°C")
    print(f"Capacity improvement: {((max(capacities) - min(capacities))/min(capacities)*100):.1f}% from cold to optimal temperature")
    print("="*50)

# %%
plot_charge_capacity_bar_graph(temp_datasets,temp_colors)
# Out:
# ...
# BATTERY CAPACITY ANALYSIS SUMMARY
# ...
# Temperature range tested: -10.0°C to 50.0°C
# Highest capacity: 1.081 Ah at 50.0°C
# Lowest capacity: 1.042 Ah at 10.0°C
# Capacity improvement: 3.7% from cold to optimal temperature
# ...

# %%
def plot_comprehensive_battery_bar_comparison(datasets, temp_colors):
    """
    Create a grouped bar chart showing multiple battery performance metrics
    across different temperatures. This provides a more comprehensive view
    of how temperature affects various aspects of battery performance.
    """
    
    # Collect multiple metrics for each temperature
    temperatures = []
    max_discharge = []  # Maximum discharge capacity
    avg_voltage = []    # Average voltage during operation
    capacity_efficiency = []  # Ratio of actual to theoretical capacity
    
    for temp, df in datasets.items():
        if not df.empty:
            temperatures.append(float(temp))
            
            # Calculate discharge capacity (same as before)
            cycle_data = df.groupby('Cycle_Index')['Discharge_Capacity(Ah)'].max()
            max_discharge.append(cycle_data.max() if not cycle_data.empty else 0)
            
            # Calculate average operating voltage
            avg_voltage.append(df['Voltage(V)'].mean())
            
            # Calculate efficiency (normalized to the theoretical maximum)
            theoretical_max = 1.1  # Assumed theoretical maximum for A123 batteries
            efficiency = (cycle_data.max() / theoretical_max * 100) if not cycle_data.empty else 0
            capacity_efficiency.append(efficiency)
    
    # Sort all data by temperature
    sorted_indices = sorted(range(len(temperatures)), key=lambda i: temperatures[i])
    temperatures = [temperatures[i] for i in sorted_indices]
    max_discharge = [max_discharge[i] for i in sorted_indices]
    avg_voltage = [avg_voltage[i] for i in sorted_indices]
    capacity_efficiency = [capacity_efficiency[i] for i in sorted_indices]
    
    # Create grouped bar chart
    x = range(len(temperatures))
    width = 0.25  # Width of individual bars
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
    
    # First subplot: Capacity comparison
    bars1 = ax1.bar([i - width for i in x], max_discharge, width, 
                    label='Discharge Capacity (Ah)', color='skyblue', alpha=0.8)
    bars2 = ax1.bar(x, capacity_efficiency, width, 
                    label='Capacity Efficiency (%)', color='lightcoral', alpha=0.8)
    
    ax1.set_xlabel('Temperature (°C)', fontsize=12)
    ax1.set_ylabel('Capacity Metrics', fontsize=12)
    ax1.set_title('Battery Capacity Metrics by Temperature', fontsize=14, fontweight='bold')
    ax1.set_xticks(x)
    ax1.set_xticklabels([f'{temp}°C' for temp in temperatures])
    ax1.legend()
    ax1.grid(axis='y', alpha=0.3)
    
    # Second subplot: Voltage comparison
    bars3 = ax2.bar(x, avg_voltage, width*2, 
                    color=[temp_colors[str(int(temp))] for temp in temperatures], alpha=0.8)
    
    ax2.set_xlabel('Temperature (°C)', fontsize=12)
    ax2.set_ylabel('Average Voltage (V)', fontsize=12)
    ax2.set_title('Average Operating Voltage by Temperature', fontsize=14, fontweight='bold')
    ax2.set_xticks(x)
    ax2.set_xticklabels([f'{temp}°C' for temp in temperatures])
    ax2.grid(axis='y', alpha=0.3)
    
    # Add value labels on bars
    for bars in [bars1, bars2, bars3]:
        for bar in bars:
            height = bar.get_height()
            ax = bar.axes
            ax.text(bar.get_x() + bar.get_width()/2., height + height*0.01,
                   f'{height:.2f}', ha='center', va='bottom', fontsize=9)
    
    plt.tight_layout()
    plt.savefig('comprehensive_battery_bar_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_comprehensive_battery_bar_comparison(temp_datasets,temp_colors)

# %%
def debug_discharge_data(datasets):
    """
    Debug function to understand the data structure and identify issues
    """
    print("="*60)
    print("BATTERY DATA DEBUGGING ANALYSIS")
    print("="*60)
    
    for temp, df in datasets.items():
        print(f"\n--- Temperature: {temp}°C ---")
        print(f"Total rows: {len(df)}")
        print(f"Date range: {df['Date_Time'].min()} to {df['Date_Time'].max()}")
        
        # Examine current values
        print(f"\nCurrent Analysis:")
        print(f"Current range: {df['Current(A)'].min():.3f} to {df['Current(A)'].max():.3f}")
        print(f"Positive current count: {len(df[df['Current(A)'] > 0])}")
        print(f"Negative current count: {len(df[df['Current(A)'] < 0])}")
        print(f"Zero current count: {len(df[df['Current(A)'] == 0])}")
        
        # Examine capacity values
        print(f"\nCapacity Analysis:")
        print(f"Discharge capacity range: {df['Discharge_Capacity(Ah)'].min():.3f} to {df['Discharge_Capacity(Ah)'].max():.3f}")
        print(f"Non-zero discharge capacity count: {len(df[df['Discharge_Capacity(Ah)'] > 0])}")
        
        # Examine cycles
        print(f"\nCycle Analysis:")
        print(f"Available cycles: {sorted(df['Cycle_Index'].unique())}")
        
        # Check for discharge data specifically
        discharge_candidates = df[df['Current(A)'] < -0.01]  # Very small threshold
        print(f"Potential discharge data points: {len(discharge_candidates)}")
        
        if len(discharge_candidates) > 0:
            print(f"Discharge current range: {discharge_candidates['Current(A)'].min():.3f} to {discharge_candidates['Current(A)'].max():.3f}")
        
        # Show a sample of the data
        print(f"\nSample data (first 5 rows):")
        print(df[['Current(A)', 'Voltage(V)', 'Discharge_Capacity(Ah)', 'Cycle_Index']].head())
        
        print("-" * 50)

# Run this first to understand your data
debug_discharge_data(temp_datasets)
# Out:
# ...
# BATTERY DATA DEBUGGING ANALYSIS
# ...
#
# --- Temperature: -10°C ---
# Total rows: 29785
# Date range: 2012-06-29 16:51:38 to 2012-07-01 13:02:14
#
# Current Analysis:
# Current range: -0.050 to 1.151
# Positive current count: 14360
# Negative current count: 15244
# Zero current count: 181
#
# Capacity Analysis:
# Discharge capacity range: 0.000 to 1.060
# Non-zero discharge capacity count: 29656
#
# Cycle Analysis:
# Available cycles: [1]
# Potential discharge data points: 15244
# Discharge current range: -0.050 to -0.050
#
# Sample data (first 5 rows):
#    Current(A)  Voltage(V)  Discharge_Capacity(Ah)  Cycle_Index
# 0    0.000000    3.480732                     0.0            1
# 1    1.151195    3.917767                     0.0            1
# 2    0.205528    3.601070                     0.0            1
# 3    0.174495    3.601070                     0.0            1
# 4    0.151629    3.601070                     0.0            1
# --------------------------------------------------
# ...

# %%
def plot_corrected_discharge_curves(datasets, temp_colors):
    """
    Corrected discharge plotting function using the right current threshold
    """
    
    plt.figure(figsize=(14, 8))
    
    for temp, df in datasets.items():
        print(f"Processing {temp}°C...")
        
        # CORRECTED: Use -0.01 threshold instead of -0.1
        # Since your discharge current is exactly -0.050A
        discharge_data = df[
            (df['Current(A)'] < -0.01) &  # This will catch -0.050A
            (df['Discharge_Capacity(Ah)'] > 0) &  # Only positive discharge capacity
            (df['Cycle_Index'] == 1)  # First cycle only
        ].copy()
        
        print(f"  Found {len(discharge_data)} discharge data points")
        
        if len(discharge_data) > 10:
            # Sort by discharge capacity for smooth curve
            discharge_data = discharge_data.sort_values('Discharge_Capacity(Ah)')
            
            # Plot the discharge curve
            plt.plot(discharge_data['Discharge_Capacity(Ah)'], 
                    discharge_data['Voltage(V)'], 
                    label=f'{temp}°C', 
                    color=temp_colors[temp], 
                    linewidth=2.5, 
                    alpha=0.8)
            
            print(f"  Successfully plotted curve for {temp}°C")
            print(f"    Capacity range: {discharge_data['Discharge_Capacity(Ah)'].min():.3f} to {discharge_data['Discharge_Capacity(Ah)'].max():.3f} Ah")
            print(f"    Voltage range: {discharge_data['Voltage(V)'].min():.3f} to {discharge_data['Voltage(V)'].max():.3f} V")
    
    plt.title('Battery Discharge Curves by Temperature (Corrected)', fontsize=16)
    plt.xlabel('Discharge Capacity (Ah)', fontsize=14)
    plt.ylabel('Voltage (V)', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=12, title='Temperature (°C)', loc='upper right')
    
    # Set appropriate axis limits based on your data
    plt.xlim(0, 1.1)  # From 0 to slightly above max capacity
    plt.ylim(2.5, 4.0)  # Typical Li-ion voltage range
    
    plt.tight_layout()
    plt.savefig('corrected_discharge_curves.png', dpi=300, bbox_inches='tight')
    plt.show()

# Run the corrected function
plot_corrected_discharge_curves(temp_datasets, temp_colors)
# Out:
# Processing -10°C...
#   Found 15244 discharge data points
#   Successfully plotted curve for -10°C
#     Capacity range: 0.000 to 1.060 Ah
#     Voltage range: 2.000 to 3.519 V
# Processing 0°C...
#   Found 15215 discharge data points
#   Successfully plotted curve for 0°C
#     Capacity range: 0.000 to 1.058 Ah
#     Voltage range: 2.000 to 3.510 V
# Processing 10°C...
#   Found 15006 discharge data points
#   Successfully plotted curve for 10°C
#     Capacity range: 0.000 to 1.042 Ah
#     Voltage range: 2.000 to 3.476 V
# Processing 20°C...
#   Found 15319 discharge data points
#   Successfully plotted curve for 20°C
#     Capacity range: 0.000 to 1.065 Ah
#     Voltage range: 2.000 to 3.500 V
# Processing 25°C...
#   Found 15314 discharge data points
#   Successfully plotted curve for 25°C
#     Capacity range: 0.000 to 1.064 Ah
#     Voltage range: 2.000 to 3.497 V
# Processing 30°C...
#   Found 15431 discharge data points
#   Successfully plotted curve for 30°C
# ...

# %%
def debug_charging_filters(datasets):
    """
    Debug each filtering condition to see where data is being lost
    """
    
    print("="*80)
    print("DETAILED CHARGING DATA FILTER ANALYSIS")
    print("="*80)
    
    for temp, df in datasets.items():
        print(f"\n--- Temperature: {temp}°C ---")
        print(f"Total rows: {len(df)}")
        
        # Step 1: Filter by current only
        current_filter = df['Current(A)'] > 1.0
        step1_data = df[current_filter]
        print(f"After Current > 1.0A: {len(step1_data)} rows")
        
        # Step 2: Add cycle filter  
        cycle_filter = current_filter & (df['Cycle_Index'] == 1)
        step2_data = df[cycle_filter]
        print(f"After adding Cycle_Index == 1: {len(step2_data)} rows")
        
        # Step 3: Add capacity filter
        capacity_filter = cycle_filter & (df['Charge_Capacity(Ah)'] > 0)
        step3_data = df[capacity_filter]
        print(f"After adding Charge_Capacity > 0: {len(step3_data)} rows")
        
        # Analyze the charge capacity values
        charge_current_data = df[df['Current(A)'] > 1.0]
        if len(charge_current_data) > 0:
            charge_cap_range = charge_current_data['Charge_Capacity(Ah)']
            print(f"Charge capacity range during charging: {charge_cap_range.min():.3f} to {charge_cap_range.max():.3f}")
            print(f"Zero charge capacity count: {len(charge_current_data[charge_current_data['Charge_Capacity(Ah)'] == 0])}")
            print(f"Positive charge capacity count: {len(charge_current_data[charge_current_data['Charge_Capacity(Ah)'] > 0])}")
        
        print("-" * 50)

# Run the detailed debugging
debug_charging_filters(temp_datasets)
# Out:
# ...
# DETAILED CHARGING DATA FILTER ANALYSIS
# ...
#
# --- Temperature: -10°C ---
# Total rows: 29785
# After Current > 1.0A: 1 rows
# After adding Cycle_Index == 1: 1 rows
# After adding Charge_Capacity > 0: 1 rows
# Charge capacity range during charging: 0.000 to 0.000
# Zero charge capacity count: 0
# Positive charge capacity count: 1
# --------------------------------------------------
#
# --- Temperature: 0°C ---
# Total rows: 30249
# After Current > 1.0A: 1 rows
# After adding Cycle_Index == 1: 1 rows
# After adding Charge_Capacity > 0: 1 rows
# Charge capacity range during charging: 0.000 to 0.000
# Zero charge capacity count: 0
# Positive charge capacity count: 1
# --------------------------------------------------
#
# --- Temperature: 10°C ---
# Total rows: 31898
# After Current > 1.0A: 1 rows
# After adding Cycle_Index == 1: 1 rows
# After adding Charge_Capacity > 0: 1 rows
# Charge capacity range during charging: 0.000 to 0.000
# Zero charge capacity count: 0
# ...

# %%
def find_actual_charging_currents(datasets):
    """
    Find the actual charging current values for each temperature
    """
    
    print("="*80)
    print("ACTUAL CHARGING CURRENT ANALYSIS")
    print("="*80)
    
    for temp, df in datasets.items():
        print(f"\n--- Temperature: {temp}°C ---")
        
        # Get all positive currents and their frequencies
        positive_currents = df[df['Current(A)'] > 0]['Current(A)']
        current_counts = positive_currents.value_counts().sort_index(ascending=False).head(10)
        
        print("Top 10 positive current values and their frequencies:")
        for current, count in current_counts.items():
            print(f"  {current:.6f}A: {count} occurrences")
        
        # Check if there are different charging current patterns
        significant_currents = positive_currents[positive_currents > 0.5].value_counts()
        print(f"\nSignificant currents (>0.5A): {len(significant_currents)} different values")
        
        if len(significant_currents) > 0:
            max_current = significant_currents.index[0]
            max_count = significant_currents.iloc[0]
            print(f"Most common significant current: {max_current:.6f}A ({max_count} times)")

# Analyze actual current values
find_actual_charging_currents(temp_datasets)
# Out:
# ...
# ACTUAL CHARGING CURRENT ANALYSIS
# ...
#
# --- Temperature: -10°C ---
# Top 10 positive current values and their frequencies:
#   1.151195A: 1 occurrences
#   0.205528A: 1 occurrences
#   0.174495A: 1 occurrences
#   0.151629A: 1 occurrences
#   0.133118A: 1 occurrences
#   0.118055A: 1 occurrences
#   0.105533A: 1 occurrences
#   0.095008A: 1 occurrences
#   0.085934A: 1 occurrences
#   0.078130A: 1 occurrences
#
# Significant currents (>0.5A): 1 different values
# Most common significant current: 1.151195A (1 times)
#
# --- Temperature: 0°C ---
# Top 10 positive current values and their frequencies:
#   1.151157A: 1 occurrences
#   0.618210A: 1 occurrences
#   0.581370A: 1 occurrences
#   0.548341A: 1 occurrences
#   0.518034A: 1 occurrences
#   0.490268A: 1 occurrences
#   0.464135A: 1 occurrences
#   0.439454A: 1 occurrences
#   0.416225A: 1 occurrences
#   0.394084A: 1 occurrences
#
# Significant currents (>0.5A): 5 different values
# ...

# %%
def create_comprehensive_battery_analysis(datasets, temp_colors):
    """
    Create a comprehensive analysis using available data:
    - Discharge curves for all temperatures 
    - Charging curve for 25°C only
    - Combined analysis plot
    """
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))
    
    # Left plot: Discharge curves for all temperatures
    ax1.set_title('Discharge Curves (All Temperatures)', fontsize=16)
    
    for temp, df in datasets.items():
        # Use our corrected discharge filtering
        discharge_data = df[
            (df['Current(A)'] < -0.01) &  # -0.050A discharge current
            (df['Discharge_Capacity(Ah)'] > 0) &
            (df['Cycle_Index'] == 1)
        ].copy()
        
        if len(discharge_data) > 10:
            discharge_data = discharge_data.sort_values('Discharge_Capacity(Ah)')
            ax1.plot(discharge_data['Discharge_Capacity(Ah)'], 
                    discharge_data['Voltage(V)'], 
                    label=f'{temp}°C', 
                    color=temp_colors[temp], 
                    linewidth=2.5)
    
    ax1.set_xlabel('Discharge Capacity (Ah)', fontsize=14)
    ax1.set_ylabel('Voltage (V)', fontsize=14)
    ax1.legend(fontsize=12, title='Temperature (°C)')
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim(0, 1.1)
    ax1.set_ylim(2.8, 4.0)
    
    # Right plot: Charging curve for 25°C only
    ax2.set_title('Charging Curve (25°C Only)', fontsize=16)
    
    temp_25_df = datasets['25']
    charge_data_25 = temp_25_df[
        (temp_25_df['Current(A)'] > 1.17) &  # Use 25°C specific current
        (temp_25_df['Cycle_Index'] == 1) &
        (temp_25_df['Charge_Capacity(Ah)'] > 0)
    ].copy()
    
    if len(charge_data_25) > 10:
        charge_data_25 = charge_data_25.sort_values('Charge_Capacity(Ah)')
        ax2.plot(charge_data_25['Charge_Capacity(Ah)'], 
                charge_data_25['Voltage(V)'], 
                color=temp_colors['25'], 
                linewidth=3, 
                label='25°C Charging')
        
        # Add annotation explaining why only 25°C
        ax2.text(0.5, 0.95, 'Only 25°C dataset contains\nsustained charging data', 
                transform=ax2.transAxes, ha='center', va='top',
                bbox=dict(boxstyle="round,pad=0.5", facecolor='lightyellow', alpha=0.8),
                fontsize=12)
    
    ax2.set_xlabel('Charge Capacity (Ah)', fontsize=14)
    ax2.set_ylabel('Voltage (V)', fontsize=14)
    ax2.legend(fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim(0, 1.0)
    ax2.set_ylim(3.0, 4.0)
    
    plt.tight_layout()
    plt.savefig('comprehensive_battery_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # Print summary of data availability
    print("\n" + "="*60)
    print("DATA AVAILABILITY SUMMARY")
    print("="*60)
    print("Discharge data: Available for all temperatures (-10°C to 50°C)")
    print("Charging data: Only available for 25°C")
    print("Reason: Other temperatures lack sustained charging current measurements")
    print("="*60)

# Create the comprehensive analysis
create_comprehensive_battery_analysis(temp_datasets, temp_colors)
# Out:
# ...
# DATA AVAILABILITY SUMMARY
# ...
# Discharge data: Available for all temperatures (-10°C to 50°C)
# Charging data: Only available for 25°C
# Reason: Other temperatures lack sustained charging current measurements
# ...

# %%
def explain_data_limitations(datasets):
    """
    Create a visualization explaining the data collection differences
    """
    
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Show the charging current frequency for each temperature
    temps = []
    charging_points = []
    colors = []
    
    for temp, df in datasets.items():
        temps.append(f'{temp}°C')
        # Count sustained charging measurements (current > 1.0A)
        charging_count = len(df[df['Current(A)'] > 1.0])
        charging_points.append(charging_count)
        colors.append(temp_colors[temp])
    
    bars = ax.bar(temps, charging_points, color=colors, alpha=0.7, edgecolor='black')
    
    # Add value labels on bars
    for bar, count in zip(bars, charging_points):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2., height + 5,
               f'{count}', ha='center', va='bottom', fontsize=12, fontweight='bold')
    
    ax.set_title('Charging Data Availability by Temperature', fontsize=16)
    ax.set_xlabel('Temperature', fontsize=14)
    ax.set_ylabel('Number of Sustained Charging Measurements', fontsize=14)
    ax.grid(axis='y', alpha=0.3)
    
    # Add explanation
    ax.text(0.98, 0.98, 
           'Only 25°C contains sufficient\ncharging data for curve analysis\n\n'
           'Other temperatures have only\nbrief current measurements\nduring test transitions', 
           transform=ax.transAxes, ha='right', va='top',
           bbox=dict(boxstyle="round,pad=0.5", facecolor='lightblue', alpha=0.8),
           fontsize=12)
    
    plt.tight_layout()
    plt.savefig('data_availability_explanation.png', dpi=300, bbox_inches='tight')
    plt.show()

# Show the data limitation explanation
explain_data_limitations(temp_datasets)
